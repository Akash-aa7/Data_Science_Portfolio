# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-verma998/Data_Science_Portfolio/blob/master/reading_data_in_zip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd Twitter_June2021/
# Out:
# /content/drive/.shortcut-targets-by-id/1My235CGavtVt6o8S8TjAX4pH94gyWQdC/Twitter_June2021

# %%
ls
# Out:
# geoEurope_2021060100.zip  geoEurope_2021061023.zip  geoEurope_2021062100.zip
# geoEurope_2021060101.zip  geoEurope_2021061100.zip  geoEurope_2021062101.zip
# geoEurope_2021060102.zip  geoEurope_2021061101.zip  geoEurope_2021062102.zip
# geoEurope_2021060103.zip  geoEurope_2021061102.zip  geoEurope_2021062103.zip
# geoEurope_2021060104.zip  geoEurope_2021061103.zip  geoEurope_2021062104.zip
# geoEurope_2021060105.zip  geoEurope_2021061104.zip  geoEurope_2021062105.zip
# geoEurope_2021060106.zip  geoEurope_2021061105.zip  geoEurope_2021062106.zip
# geoEurope_2021060107.zip  geoEurope_2021061106.zip  geoEurope_2021062107.zip
# geoEurope_2021060108.zip  geoEurope_2021061107.zip  geoEurope_2021062108.zip
# geoEurope_2021060109.zip  geoEurope_2021061109.zip  geoEurope_2021062109.zip
# geoEurope_2021060110.zip  geoEurope_2021061110.zip  geoEurope_2021062110.zip
# geoEurope_2021060111.zip  geoEurope_2021061111.zip  geoEurope_2021062111.zip
# ...

# %%
import glob
files_name = glob.glob("*")

# %%
files_name
# Out:
# ['geoEurope_2021060101.zip',
#  'geoEurope_2021060102.zip',
#  'geoEurope_2021060104.zip',
#  'geoEurope_2021060103.zip',
#  'geoEurope_2021060105.zip',
#  'geoEurope_2021060109.zip',
#  'geoEurope_2021060108.zip',
#  'geoEurope_2021060113.zip',
#  'geoEurope_2021060111.zip',
#  'geoEurope_2021060112.zip',
#  'geoEurope_2021060106.zip',
#  'geoEurope_2021060107.zip',
#  'geoEurope_2021060115.zip',
#  'geoEurope_2021060117.zip',
#  'geoEurope_2021060116.zip',
#  'geoEurope_2021060110.zip',
#  'geoEurope_2021060114.zip',
#  'geoEurope_2021060120.zip',
#  'geoEurope_2021060119.zip',
#  'geoEurope_2021060123.zip',
#  'geoEurope_2021060118.zip',
#  'geoEurope_2021060208.zip',
#  'geoEurope_2021060203.zip',
#  'geoEurope_2021060121.zip',
#  'geoEurope_2021060200.zip',
#  'geoEurope_2021060207.zip',
#  'geoEurope_2021060201.zip',
#  'geoEurope_2021060206.zip',
#  'geoEurope_2021060202.zip',
#  'geoEurope_2021060122.zip',
#  'geoEurope_2021060213.zip',
#  'geoEurope_2021060211.zip',
# ...

# %%
import shutil
import os

# %%
for file in files_name:
  print(file)
  os.system("unzip "+file)
# Out:
# geoEurope_2021060101.zip
# geoEurope_2021060102.zip
# geoEurope_2021060104.zip
# geoEurope_2021060103.zip
# geoEurope_2021060105.zip
# geoEurope_2021060109.zip
# geoEurope_2021060108.zip
# geoEurope_2021060113.zip
# geoEurope_2021060111.zip
# geoEurope_2021060112.zip
# geoEurope_2021060106.zip
# geoEurope_2021060107.zip
# geoEurope_2021060115.zip
# geoEurope_2021060117.zip
# geoEurope_2021060116.zip
# geoEurope_2021060110.zip
# geoEurope_2021060114.zip
# geoEurope_2021060120.zip
# geoEurope_2021060119.zip
# geoEurope_2021060123.zip
# geoEurope_2021060118.zip
# geoEurope_2021060208.zip
# geoEurope_2021060203.zip
# geoEurope_2021060121.zip
# geoEurope_2021060200.zip
# geoEurope_2021060207.zip
# geoEurope_2021060201.zip
# geoEurope_2021060206.zip
# geoEurope_2021060202.zip
# geoEurope_2021060122.zip
# geoEurope_2021060213.zip
# geoEurope_2021060211.zip
# geoEurope_2021060212.zip
# geoEurope_2021060205.zip
# geoEurope_2021060204.zip
# geoEurope_2021060209.zip
# geoEurope_2021060210.zip
# ...

# %%
import glob
files_name = glob.glob("geoEurope/*")

# %%
files_name
# Out:
# ['geoEurope/geoEurope_2021060101.json',
#  'geoEurope/geoEurope_2021060102.json',
#  'geoEurope/geoEurope_2021060104.json',
#  'geoEurope/geoEurope_2021060103.json',
#  'geoEurope/geoEurope_2021060105.json',
#  'geoEurope/geoEurope_2021060109.json',
#  'geoEurope/geoEurope_2021060108.json',
#  'geoEurope/geoEurope_2021060113.json',
#  'geoEurope/geoEurope_2021060111.json',
#  'geoEurope/geoEurope_2021060112.json',
#  'geoEurope/geoEurope_2021060106.json',
#  'geoEurope/geoEurope_2021060107.json',
#  'geoEurope/geoEurope_2021060115.json',
#  'geoEurope/geoEurope_2021060117.json',
#  'geoEurope/geoEurope_2021060116.json',
#  'geoEurope/geoEurope_2021060110.json',
#  'geoEurope/geoEurope_2021060114.json',
#  'geoEurope/geoEurope_2021060120.json',
#  'geoEurope/geoEurope_2021060119.json',
#  'geoEurope/geoEurope_2021060123.json',
#  'geoEurope/geoEurope_2021060118.json',
#  'geoEurope/geoEurope_2021060208.json',
#  'geoEurope/geoEurope_2021060203.json',
# ...

# %%
import pandas as pd

# %%
data = pd.read_json('geoEurope/geoEurope_2021060100.json',lines=True)

# %%
data.columns
# Out:
# Index(['coordinates', 'user', 'quote_count', 'place', 'geo', 'id',
#        'created_at', 'retweet_count', 'is_quote_status', 'in_reply_to_user_id',
#        'source', 'retweeted', 'in_reply_to_status_id_str', 'text', 'id_str',
#        'filter_level', 'timestamp_ms', 'in_reply_to_user_id_str', 'lang',
#        'in_reply_to_screen_name', 'in_reply_to_status_id', 'contributors',
#        'favorite_count', 'entities', 'favorited', 'truncated', 'reply_count',
#        'display_text_range', 'possibly_sensitive', 'extended_tweet',
#        'quoted_status_id_str', 'quoted_status_id', 'quoted_status',
#        'quoted_status_permalink', 'extended_entities'],
#       dtype='object')

# %%
pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1My235CGavtVt6o8S8TjAX4pH94gyWQdC/Twitter_June2021'

# %%
final_data=pd.DataFrame(columns=['coordinates', 'user', 'quote_count', 'place', 'geo', 'id','created_at','text', 'id_str','timestamp_ms','in_reply_to_user_id_str','lang','entities','reply_count'])
for file_name in files_name[:10]:
  data = pd.read_json(file_name,lines=True)
  data = data[['coordinates', 'user', 'quote_count', 'place', 'geo', 'id','created_at','text', 'id_str','timestamp_ms','in_reply_to_user_id_str','lang','entities','reply_count']]
  final_data = pd.concat([final_data,data])

# %%
final_data
# Out:
#                                              coordinates  ... reply_count
# 0      {'type': 'Point', 'coordinates': [13.435, 52.4...  ...           0
# 1      {'type': 'Point', 'coordinates': [-1.48805556,...  ...           0
# 2                                                   None  ...           0
# 3      {'type': 'Point', 'coordinates': [8.98777778, ...  ...           0
# 4      {'type': 'Point', 'coordinates': [8.1297247, 4...  ...           0
# ...                                                  ...  ...         ...
# 22161                                               None  ...           0
# 22162                                               None  ...           0
# 22163                                               None  ...           0
# 22164                                               None  ...           0
# 22165                                               None  ...           0
#
# [128870 rows x 14 columns]

# %%
final.to_csv("final_data.csv")
